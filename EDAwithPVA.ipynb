# %%
import pandas as pd
import seaborn as sns

# %%
df =  pd.read_csv('D:\Data Science\data sets\Future-500.csv')

# %%
df.tail(10)
# Out:
#       ID              Name             Industry  Inception  Employees State  \
# 490  491       Comparejson         Construction     2013.0      125.0    IL
# 491  492   Pickledcanoeing               Retail     2012.0       16.0    OH
# 492  493        Assurehelp          IT Services     2014.0       10.0    MN
# 493  494   Shrimpssecurity  Government Services     2009.0      104.0    DC
# 494  495   Rawfishcomplete   Financial Services     2012.0      124.0    CA
# 495  496  Buretteadmirable          IT Services     2009.0       93.0    ME
# 496  497  Inventtremendous         Construction     2009.0       24.0    MN
# 497  498    Overviewparrot               Retail     2011.0     7125.0    TX
# 498  499        Belaguerra          IT Services     2010.0      140.0    MI
# 499  500       Allpossible          IT Services     2011.0       24.0    CA
#
#                  City       Revenue           Expenses      Profit  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           500 non-null    int64
#  1   Name         500 non-null    object
#  2   Industry     498 non-null    object
#  3   Inception    499 non-null    float64
#  4   Employees    498 non-null    float64
#  5   State        496 non-null    object
#  6   City         500 non-null    object
#  7   Revenue      498 non-null    object
#  8   Expenses     497 non-null    object
#  9   Profit       498 non-null    float64
#  10  Growth       499 non-null    object
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  2 non-null      object
#  13  Unnamed: 13  2 non-null      object
#  14  Unnamed: 14  2 non-null      object
#  15  Unnamed: 15  2 non-null      object
#  16  Unnamed: 16  2 non-null      object
#  17  Unnamed: 17  3 non-null      object
# ...

# %%
df.describe()
# Out:
#                ID    Inception    Employees        Profit  Unnamed: 11
# count  500.000000   499.000000   498.000000  4.980000e+02          0.0
# mean   250.500000  2010.174349   148.610442  6.539474e+06          NaN
# std    144.481833     3.228211   397.353657  3.869934e+06          NaN
# min      1.000000  1999.000000     1.000000  1.243400e+04          NaN
# 25%    125.750000  2009.000000    27.250000  3.272074e+06          NaN
# 50%    250.500000  2011.000000    56.000000  6.513366e+06          NaN
# 75%    375.250000  2012.000000   126.000000  9.303951e+06          NaN
# max    500.000000  2014.000000  7125.000000  1.962453e+07          NaN

# %%
df.isnull().any().sum()
# Out:
# 20

# %%
from pandas_visual_analysis import VisualAnalysis

# %%
VisualAnalysis(df)

# %%
#To install 

# !pip install pandas_visual_analysis
